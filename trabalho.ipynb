# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
titanic_df = pd.read_csv("datasets/titanic.csv")

# %%
titanic_df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0      male  22.0                        1                        0   7.2500
# 1    female  38.0                        1                        0  71.2833
# 2    female  26.0                        0                        0   7.9250
# 3    female  35.0                        1                        0  53.1000
# 4      male  35.0                        0                        0   8.0500
# ..      ...   ...                      ...                      ...      ...
# 882    male  27.0                        0                        0  13.0000
# 883  female  19.0                        0                        0  30.0000
# 884  female   7.0                        1                        2  23.4500
# 885    male  26.0                        0                        0  30.0000
# 886    male  32.0                        0                        0   7.7500
#
# [887 rows x 8 columns]

# %% [markdown]
# ### 3. Para as variáveis quantitativas Age e Fare:
# - Calcular medidas de tendência central (média, mediana) e
# - Medidas de dispersão (desvio padrão, mínimo, máximo);
# - Calcular quartis e percentis 10 e 90 de Age.

# %%
media_idade = titanic_df.Age.mean()
mediana_idade = titanic_df.Age.median()

media_fare = titanic_df.Fare.mean()
mediana_fare = titanic_df.Fare.median()

# %%
desvio_padrao_idade = titanic_df.Age.std()
desvio_padrao_fare = titanic_df.Fare.std()

minimo_idade = titanic_df.Age.min()
maximo_idade = titanic_df.Age.max()

minimo_Fare = titanic_df.Fare.min()
maximo_Fare = titanic_df.Fare.max()

# %%
percentil_10_idade = titanic_df.Age.quantile(.10)
percentil_90_idade = titanic_df.Age.quantile(.90)

percentil_90_fare = titanic_df.Fare.quantile(.10)
percentil_90_fare = titanic_df.Fare.quantile(.90)

# %%
plt.hist(titanic_df.Age)
# Out:
# (array([ 63.,  51., 242., 211., 142.,  88.,  49.,  28.,  11.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(titanic_df.Age,titanic_df.Fare)

# %%
titanic_df[["Age","Fare"]].corr('pearson')
# Out:
#            Age      Fare
# Age   1.000000  0.112329
# Fare  0.112329  1.000000

# %% [markdown]
# ## Dataset 2 - Eleições

# %%
eleicoes_df = pd.read_csv("datasets/eleicoes.csv", names=["Estado","NumeroCand","Dinheiro","Votos"],skiprows=1)

# %%
eleicoes_df.Estado = eleicoes_df.Estado.str.strip()

# %%
eleicoes_df.head()
# Out:
#   Estado  NumeroCand   Dinheiro  Votos
# 0     AC        1919   35504.34    515
# 1     AC        1212  397136.76  11397
# 2     AC        5012    1580.00     15
# 3     AC        1321   66093.33   1913
# 4     AC        1144  296327.21  13610

# %% [markdown]
# ### Histogramas por estado (3 estados escolhidos pelo aluno)
# ○ Escolher 3 estados (UFs) quaisquer.
# ○ Para cada um desses estados:
# - Um histograma do número de votos (votos);
# - Um histograma do dinheiro de campanha (dinheiro).
# ○ Em cada caso, comentar brevemente (2–3 linhas) a forma das distribuições (concentração, cauda longa, presença de valores extremos, etc.).

# %%
eleicoes_df_CE = eleicoes_df[eleicoes_df.Estado == "CE"]
eleicoes_df_SP = eleicoes_df[eleicoes_df.Estado == "SP"]
eleicoes_df_RS = eleicoes_df[eleicoes_df.Estado == "RS"]

# %%
plt.hist(eleicoes_df_CE.Votos,bins=50)
plt.xlabel("Quantidade de Votos")
plt.ylabel("Quantidade de Candidatos")

plt.show()

# %%
plt.hist(eleicoes_df_SP.Votos,bins=50)
plt.xlabel("Quantidade de Votos")
plt.ylabel("Quantidade de Candidatos")

plt.show()

# %%
plt.hist(eleicoes_df_RS.Votos,bins=50)
plt.xlabel("Quantidade de Votos")
plt.ylabel("Quantidade de Candidatos")

plt.show()

# %% [markdown]
# #### Dinheiro

# %%
plt.hist(eleicoes_df_CE.Dinheiro,bins=100)
plt.xlabel("Quantidade de Dinheiro")
plt.ylabel("Quantidade de Candidatos")

plt.show()

# %%
plt.hist(eleicoes_df_SP.Dinheiro,bins=100)
plt.xlabel("Quantidade de Dinheiro")
plt.ylabel("Quantidade de Candidatos")

plt.show()

# %%
plt.hist(eleicoes_df_RS.Dinheiro,bins=100)
plt.xlabel("Quantidade de Dinheiro")
plt.ylabel("Quantidade de Candidatos")

plt.show()

# %% [markdown]
# ### Gráficos de dispersão e correlação (3 estados)
# Para os mesmos 3 estados escolhidos no item anterior:
# - construir um gráfico de dispersão entre dinheiro (eixo x) e votos (eixo y);
# - calcular o coeficiente de correlação de Pearson entre dinheiro e votos em cada estado.
#
# ○ Comentar se a correlação é fraca, moderada ou forte, e se é positiva ou negativa, relacionando com o padrão visual do gráfico de dispersão.

# %%
plt.scatter(eleicoes_df_CE.Dinheiro, eleicoes_df_CE.Votos)

plt.xlabel("Dinheiro")
plt.ylabel("Votos")

plt.show()

# %%
plt.scatter(eleicoes_df_SP.Dinheiro, eleicoes_df_SP.Votos)

plt.xlabel("Dinheiro")
plt.ylabel("Votos")

plt.show()

# %%
plt.scatter(eleicoes_df_RS.Dinheiro, eleicoes_df_RS.Votos)

plt.xlabel("Dinheiro")
plt.ylabel("Votos")

plt.show()

# %%
eleicoes_df_CE[["Votos","Dinheiro"]].corr('pearson')
# Out:
#              Votos  Dinheiro
# Votos     1.000000  0.737909
# Dinheiro  0.737909  1.000000

# %%
eleicoes_df_SP[["Votos","Dinheiro"]].corr('pearson')
# Out:
#              Votos  Dinheiro
# Votos     1.000000  0.483247
# Dinheiro  0.483247  1.000000

# %%
eleicoes_df_RS[["Votos","Dinheiro"]].corr('pearson')["Dinheiro"]["Votos"]
# Out:
# np.float64(0.8365592671378882)

# %% [markdown]
# ### Correlação por estado – Brasil inteiro
# ○ Considerando todos os estados presentes no dataset:
# - calcular, para cada UF, o coeficiente de correlação de Pearson entre dinheiro e votos;
# - apresentar os resultados em uma tabela com pelo menos as colunas: UF, correlação dinheiro votos.

# %%
for estado in eleicoes_df["Estado"].unique():
    corr_estado = eleicoes_df[eleicoes_df["Estado"]==estado][["Votos","Dinheiro"]].corr('pearson')["Dinheiro"]["Votos"]
    print(f"Estado: {estado} - Correlação: {corr_estado:.4}")
# Out:
# Estado: AC - Correlação: 0.7227
# Estado: AL - Correlação: 0.8404
# Estado: AM - Correlação: 0.9055
# Estado: AP - Correlação: 0.5669
# Estado: BA - Correlação: 0.6981
# Estado: CE - Correlação: 0.7379
# Estado: ES - Correlação: 0.8222
# Estado: GO - Correlação: 0.6679
# Estado: MA - Correlação: 0.6856
# Estado: MG - Correlação: 0.8067
# Estado: MS - Correlação: 0.7789
# Estado: MT - Correlação: 0.8669
# Estado: PA - Correlação: 0.7146
# Estado: PB - Correlação: 0.8553
# Estado: PE - Correlação: 0.7283
# Estado: PI - Correlação: 0.6564
# Estado: PR - Correlação: 0.7287
# Estado: RJ - Correlação: 0.5647
# Estado: RN - Correlação: 0.8825
# Estado: RO - Correlação: 0.6833
# Estado: RR - Correlação: 0.5989
# Estado: RS - Correlação: 0.8366
# Estado: SC - Correlação: 0.8698
# Estado: SE - Correlação: 0.6849
# Estado: TO - Correlação: 0.7698
# Estado: SP - Correlação: 0.4832

# %% [markdown]
# ### Medidas de tendência central e dispersão por estado
# ○ Construir uma tabela-resumo por estado (UF) contendo, para as variáveis votos e dinheiro, pelo menos as seguintes medidas:
# - média
# - mediana
# - desvio padrão
# - mínimo
# - máximo
# - primeiro e terceiro quartis (Q1 e Q3)
# - A tabela deve ter, nas linhas, os estados, e nas colunas, as medidas para votos e para dinheiro.

# %%
tabela_resumo = eleicoes_df.groupby('Estado').agg(
    votos_media=('Votos', 'mean'),
    votos_mediana=('Votos', 'median'),
    votos_desvio=('Votos', 'std'),
    votos_min=('Votos', 'min'),
    votos_max=('Votos', 'max'),
    votos_q1=('Votos', lambda x: x.quantile(0.25)),
    votos_q3=('Votos', lambda x: x.quantile(0.75)),

    dinheiro_media=('Dinheiro', 'mean'),
    dinheiro_mediana=('Dinheiro', 'median'),
    dinheiro_desvio=('Dinheiro', 'std'),
    dinheiro_min=('Dinheiro', 'min'),
    dinheiro_max=('Dinheiro', 'max'),
    dinheiro_q1=('Dinheiro', lambda x: x.quantile(0.25)),
    dinheiro_q3=('Dinheiro', lambda x: x.quantile(0.75)),
).round(2)

print(tabela_resumo)
# Out:
#         votos_media  votos_mediana  votos_desvio  votos_min  votos_max  \
# Estado
# AC          5940.84         1645.0       8310.84          5      39844
# AL         11456.43         1021.0      27397.36          0     135929
# AM         19501.06         1051.5      43379.50          0     250916
# AP          3376.71          886.0       5093.80          0      22134
# BA         18183.50          988.0      37929.69          0     222164
# CE         19912.90         1184.0      45729.12          0     277774
# ES         10154.13         1116.0      23068.11          0     161744
# GO         19613.40          349.0      42725.96          0     274625
# MA         11770.90          971.0      25098.15          0     133575
# MG         14512.48          972.0      37704.17          0     310226
# MS          9867.40         1468.0      23458.95          0     160556
# MT         12475.34          940.0      27059.62          0     127749
# PA         19004.15         1406.5      40028.32          0     265983
# PB         17383.45         1192.5      38520.37          0     179886
# PE         25969.48         2542.0      49398.97          0     283567
# PI         15874.77          584.0      34445.09          0     134157
# PR         17241.44         1149.5      38218.00          0     200144
# RJ          7056.90          715.0      26267.58          0     464572
# RN         16126.01         1436.5      38557.78          0     191064
# RO          8820.52         2902.5      13737.63          0      61419
